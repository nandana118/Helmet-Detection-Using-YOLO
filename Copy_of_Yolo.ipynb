# %%
pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.9/914.9 kB 17.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 72.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 56.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 46.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 10.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 48.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
model=YOLO("/content/best.pt")

# %%
res=model("/content/l2_4_44.jpg")
# Out:
# image 1/1 /content/l2_4_44.jpg: 640x640 2 without helmets, 2 helmets, 9.8ms
# Speed: 13.6ms preprocess, 9.8ms inference, 389.3ms postprocess per image at shape (1, 3, 640, 640)

# %%
# !yolo task=detect mode=predict model="/content/best.pt" conf=0.60 source=/content/l2_4_44.jpg project=/content/new
# Out:
# Ultralytics 8.3.70 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 238 layers, 2,582,542 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/1 /content/l2_4_44.jpg: 640x640 1 helmet, 16.0ms
# Speed: 8.0ms preprocess, 16.0ms inference, 179.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to /content/new/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
model=YOLO('yolo11n.pt')  # file will be saved in the mentioned extension
# Out:
# ...
# 100%|██████████| 5.35M/5.35M [00:00<00:00, 179MB/s]

# %%
res=model('/content/78caef6edaa63e134035c2fcb8b56416.jpg')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-90169da231f5> in <cell line: 0>()
# ----> 1 res=model('/content/78caef6edaa63e134035c2fcb8b56416.jpg')
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/engine/model.py in __call__(self, source, stream, **kwargs)
#     178             ...     print(f"Detected {len(r)} objects in image")
#     179         """
# --> 180         return self.predict(source, stream, **kwargs)
#     181
#     182     @staticmethod
#
# /usr/local/lib/python3.11/dist-packages/ultralytics/engine/model.py in predict(self, source, stream, predictor, **kwargs)
#     556         if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     557             self.predictor.set_prompts(prompts)
# --> 558         return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
# ...

# %%
type(res)

# %%
res[0].save("image.jpg")

# %%
res1=model('/content/car_video_numplate.mp4')

# %%
c=0
for i in res1:
  i.save(f"Results/image{c}.jpg")
  c+=1

# %% [markdown]
# **Custom** **Yolo Model for Helmet detection**

# %%
# !kaggle datasets download -d "vodan37/yolo-helmethead"
# Out:
# Dataset URL: https://www.kaggle.com/datasets/vodan37/yolo-helmethead
# License(s): GNU Lesser General Public License 3.0
# ...
# 100% 3.99G/3.99G [03:03<00:00, 23.0MB/s]
# 100% 3.99G/3.99G [03:03<00:00, 23.4MB/s]

# %%
# !unzip /content/yolo-helmethead.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: yolov5_tensorrt/yolov5_tensorrt/test_result/yolov5m_640_fp32_helm/labels/output_helm_018163.txt
#   inflating: yolov5_tensorrt/yolov5_tensorrt/test_result/yolov5m_640_fp32_helm/labels/output_helm_018176.txt
#   inflating: yolov5_tensorrt/yolov5_tensorrt/test_result/yolov5m_640_fp32_helm/labels/output_helm_018191.txt
#   inflating: yolov5_tensorrt/yolov5_tensorrt/test_result/yolov5m_640_fp32_helm/labels/output_helm_018216.txt
#   inflating: yolov5_tensorrt/yolov5_tensorrt/test_result/yolov5m_640_fp32_helm/labels/output_helm_018219.txt
#   inflating: yolov5_tensorrt/yolov5_tensorrt/test_result/yolov5m_640_fp32_helm/labels/output_helm_018225.txt
#   inflating: yolov5_tensorrt/yolov5_tensorrt/test_result/yolov5m_640_fp32_helm/labels/output_helm_018237.txt
#   inflating: yolov5_tensorrt/yolov5_tensorrt/test_result/yolov5m_640_fp32_helm/labels/output_helm_018239.txt
# ...

# %%
 # !yolo task=detect mode=train model=yolo11n.pt data=/content/helm/helm/helm.yaml epochs=5 project=/content/training_results name=results
# Out:
# Ultralytics 8.3.70 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...
